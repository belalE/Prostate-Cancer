# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('PCC.testing.data.csv')

# %%
data.shape
# Out:
# (470, 105)

# %%
data
# Out:
#     STUDYID       RPT  time  death   BMI  HEIGHTBL  WEIGHTBL       ALP  \
# 0        AZ  AZ-00002   NaN    NaN  39.5     190.0     125.0  4.454347
# 1        AZ  AZ-00004   NaN    NaN  20.2     170.0      55.0  5.840642
# 2        AZ  AZ-00009   NaN    NaN  16.7     170.0      45.0  6.100319
# 3        AZ  AZ-00015   NaN    NaN  23.4     170.0      65.0  4.127134
# 4        AZ  AZ-00017   NaN    NaN  26.9     150.0      65.0  5.620401
# ..      ...       ...   ...    ...   ...       ...       ...       ...
# 465      AZ  AZ-00465   NaN    NaN  26.8     170.0      75.0  5.308268
# 466      AZ  AZ-00467   NaN    NaN  24.3     170.0      75.0  4.770685
# 467      AZ  AZ-00468   NaN    NaN  19.8     190.0      65.0  5.948035
# 468      AZ  AZ-00469   NaN    NaN  25.8     170.0      65.0  4.262680
# 469      AZ  AZ-00470   NaN    NaN  31.3     170.0      85.0  4.828314
#
#           ALT       AST  ...  AGEGRP2  RaceAsian  RaceBlack  RaceOther  \
# ...

# %%
data.groupby('AGEGRP2').count()
# Out:
#          STUDYID  RPT  time  death  BMI  HEIGHTBL  WEIGHTBL  ALP  ALT  AST  \
# AGEGRP2
# 0            160  160     0      0  160       160       160  160  160  160
# 1            217  217     0      0  217       217       217  217  217  217
# 2             93   93     0      0   93        93        93   93   93   93
#
#          ...  ECOG_C  RaceAsian  RaceBlack  RaceOther  RaceWhite  RegionAsia  \
# AGEGRP2  ...
# 0        ...     160        160        160        160        160         160
# 1        ...     217        217        217        217        217         217
# 2        ...      93         93         93         93         93          93
#
#          RegionEastEuro  RegionNorthAmer  RegionSouthAmer  RegionWestEuro
# AGEGRP2
# 0                   160              160              160             160
# 1                   217              217              217             217
# 2                    93               93               93              93
#
# [3 rows x 104 columns]

# %%
data.describe()
# Out:
#        time  death         BMI    HEIGHTBL    WEIGHTBL         ALP  \
# count   0.0    0.0  470.000000  470.000000  470.000000  470.000000
# mean    NaN    NaN   27.303872  172.424641   81.591089    5.224374
# std     NaN    NaN    4.498112    9.601561   15.492869    0.860757
# min     NaN    NaN   16.600000  150.000000   45.000000    3.465736
# 25%     NaN    NaN   24.300000  170.000000   75.000000    4.587506
# 50%     NaN    NaN   26.900000  170.000000   85.000000    5.043404
# 75%     NaN    NaN   29.700000  170.000000   85.000000    5.788426
# max     NaN    NaN   46.000000  210.000000  135.000000    7.862882
#
#               ALT         AST          CA       CREAT  ...     AGEGRP2  \
# count  470.000000  470.000000  470.000000  470.000000  ...  470.000000
# mean     3.037398    3.271907    2.353989    4.425569  ...    0.857447
# std      0.565558    0.455518    0.150801    0.246177  ...    0.720473
# min      1.609438    2.302585    1.650000    3.610918  ...    0.000000
# ...

# %%
data.groupby('ECOG_C').count()
# Out:
#         STUDYID  RPT  time  death  BMI  HEIGHTBL  WEIGHTBL  ALP  ALT  AST  \
# ECOG_C
# 0           247  247     0      0  247       247       247  247  247  247
# 1           223  223     0      0  223       223       223  223  223  223
#
#         ...  AGEGRP2  RaceAsian  RaceBlack  RaceOther  RaceWhite  RegionAsia  \
# ECOG_C  ...
# 0       ...      247        247        247        247        247         247
# 1       ...      223        223        223        223        223         223
#
#         RegionEastEuro  RegionNorthAmer  RegionSouthAmer  RegionWestEuro
# ECOG_C
# 0                  247              247              247             247
# 1                  223              223              223             223
#
# [2 rows x 104 columns]

# %%
list(data.columns)
# Out:
# ['STUDYID',
#  'RPT',
#  'time',
#  'death',
#  'BMI',
#  'HEIGHTBL',
#  'WEIGHTBL',
#  'ALP',
#  'ALT',
#  'AST',
#  'CA',
#  'CREAT',
#  'HB',
#  'LDH',
#  'NEU',
#  'PLT',
#  'PSA',
#  'TBILI',
#  'TESTO',
#  'WBC',
#  'CREACL',
#  'NA.',
#  'MG',
#  'PHOS',
#  'ALB',
#  'TPRO',
#  'RBC',
#  'LYM',
#  'BUN',
#  'CCRC',
#  'GLU',
#  'SYSTOLICBP',
#  'DIASTOLICBP',
#  'PULSE',
#  'HEMAT',
#  'SPEGRA',
#  'LYMperLEU',
#  'MONO',
#  'MONOperLEU',
#  'NEUperLEU',
#  'POT',
#  'BASOperLEU',
#  'EOS',
#  'EOSperLEU',
#  'TARGET',
#  'LYMPH_NODES',
#  'KIDNEYS',
#  'LUNGS',
#  'LIVER',
#  'PLEURA',
#  'OTHER',
#  'PROSTATE',
#  'ORCHIDECTOMY',
#  'PROSTATECTOMY',
#  'LYMPHADENECTOMY',
#  'BILATERAL_ORCHIDECTOMY',
#  'PRIOR_RADIOTHERAPY',
#  'ANALGESICS',
#  'ANTI_ANDROGENS',
#  'GLUCOCORTICOID',
#  'GONADOTROPIN',
#  'BISPHOSPHONATE',
#  'CORTICOSTEROID',
#  'IMIDAZOLE',
#  'ACE_INHIBITORS',
#  'BETA_BLOCKING',
#  'HMG_COA_REDUCT',
#  'ESTROGENS',
#  'ANTI_ESTROGENS',
#  'CEREBACC',
# ...
