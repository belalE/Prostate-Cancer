# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from scipy.stats import chi2_contingency, fisher_exact, ttest_ind
from IPython.display import display

# %%
data = pd.read_csv('PCC.individual.project.data.csv')

# %%
# data.head()

# %%
# list(data.columns)

# %% [markdown]
# ## Clean Data to get event free survival

# %%
def get_risk(patient):
    if patient.death == 1 and patient.time < 365:
        # Patient is high risk
        return 1
    elif patient.death == 0 and patient.time > 730:
        # Patient is low risk
        return 0
    else:
        # Patient needs to be dropped, insufficient data
        return 'drop'

# %%
# data.apply(get_risk, axis=1)

# %%
data['high_risk'] = data.apply(get_risk, axis=1)
data = data.loc[lambda patient: patient.high_risk != 'drop']

# %%
data = data.drop(['time', 'death'], axis=1)

# %%
data.head()
# Out:
#    STUDYID           RPT      BMI  HEIGHTBL   WEIGHTBL       ALP       ALT  \
# 2      ASC  ASC-001-0005  26.2000     167.9   73.90000  5.068904  2.639057
# 3      ASC  ASC-001-0008  26.9915     166.7   83.50879  4.812184  3.761200
# 6      ASC  ASC-001-0013  32.2000     176.9  100.70000  4.941642  2.772589
# 16     ASC  ASC-003-0002  25.8000     163.0   68.60000  6.306275  5.135798
# 21     ASC  ASC-003-0009  25.1000     178.0   79.60000  6.511745  2.079442
#
#          AST    CA     CREAT  ...  RaceAsian  RaceBlack  RaceOther  RaceWhite  \
# 2   2.890372  2.27  4.663439  ...          0          0          0          1
# 3   3.688879  2.20  4.820282  ...          0          0          0          1
# 6   3.044522  2.45  4.574711  ...          0          0          0          1
# 16  5.521461  2.25  4.574711  ...          0          0          0          1
# 21  3.526361  2.25  5.123964  ...          0          0          0          1
#
#     RegionAsia  RegionEastEuro  RegionNorthAmer  RegionSouthAmer  \
# 2            0               0                0                0
# 3            0               0                0                0
# 6            0               0                0                0
# 16           0               0                0                0
# 21           0               0                0                0
#
#     RegionWestEuro  high_risk
# 2                0          1
# 3                0          1
# 6                0          1
# 16               0          1
# 21               0          1
#
# [5 rows x 104 columns]

# %%
sns.countplot(data['high_risk'])
# Out:
# /Users/belalelsiesy/opt/anaconda3/envs/DataViz/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='high_risk', ylabel='count'>

# %% [markdown]
# ## Race

# %%
race = ['RaceAsian',
        'RaceBlack',
        'RaceOther',
        'RaceWhite']

# %%
def get_race(data):
    if data['RaceWhite'] == 1:
        return 'White'
    elif data['RaceBlack'] == 1:
        return 'Black'
    elif data['RaceAsian'] == 1:
        return 'Asian'
    else:
        return 'Other'

# %%
data['Race'] = data[race].apply(get_race, axis=1)

# %%
race_table = pd.crosstab(index=data['high_risk'], columns=data['Race'], margins=True)
race_table
# Out:
# Race       Asian  Black  Other  White  All
# high_risk
# 0              9      4      3    150  166
# 1              6     11     14    256  287
# All           15     15     17    406  453

# %%
chi = chi2_contingency(race_table)
print("chi2:  %.2f \n p:  %.2f \n dof:  %.2f \n expected: " % (chi[0], chi[1],chi[2]))
print(chi[3])
# Out:
# chi2:  6.83
#  p:  0.56
#  dof:  8.00
#  expected:
# [[  5.49668874   5.49668874   6.22958057 148.77704194 166.        ]
#  [  9.50331126   9.50331126  10.77041943 257.22295806 287.        ]
#  [ 15.          15.          17.         406.         453.        ]]

# %% [markdown]
# ## Region

# %%
region = ['RegionAsia',
          'RegionEastEuro',
          'RegionNorthAmer',
          'RegionSouthAmer',
          'RegionWestEuro']

# %%
def get_region(data):
    if data['RegionAsia'] == 1:
        return 'Asia'
    elif data['RegionEastEuro'] == 1:
        return 'EastEuro'
    elif data['RegionNorthAmer'] == 1:
        return 'NorthAmer'
    elif data['RegionSouthAmer'] == 1:
        return 'SouthAmer'
    else:
        return 'WestEuro'

# %%
data['Region'] = data[region].apply(get_region, axis=1)

# %%
region_table = pd.crosstab(
    index=data['high_risk'], columns=data['Region'], margins=True)
region_table
# Out:
# Region     EastEuro  NorthAmer  SouthAmer  WestEuro  All
# high_risk
# 0                26         23         25        92  166
# 1                50         37         19       181  287
# All              76         60         44       273  453

# %%
chi = chi2_contingency(region_table)
print("chi2:  %.2f \n p:  %.2f \n dof:  %.2f \n expected: " % (chi[0], chi[1],chi[2]))
print(chi[3])
# Out:
# chi2:  9.00
#  p:  0.34
#  dof:  8.00
#  expected:
# [[ 27.84988962  21.98675497  16.12362031 100.0397351  166.        ]
#  [ 48.15011038  38.01324503  27.87637969 172.9602649  287.        ]
#  [ 76.          60.          44.         273.         453.        ]]

# %%
for i in range(101):
    print(" {0} - {1}".format(data.columns[i], data.iloc[200][i]))
# Out:
#  STUDYID - VEN
#  RPT - VEN-206108302
#  BMI - 23.1
#  HEIGHTBL - 172.0
#  WEIGHTBL - 68.4
#  ALP - 4.094344562
#  ALT - 2.564949357
#  AST - 3.295836866
#  CA - 2.44
#  CREAT - 4.553876892
#  HB - 12.3
#  LDH - 5.319077385
#  NEU - 1.481604541
#  PLT - 379.0
#  PSA - 2.424802726
#  TBILI - 2.079441542
#  TESTO - -0.510825624
#  WBC - 2.054123734
#  CREACL - 4.019553818
#  NA. - 137.0
#  MG - 0.019802627
#  PHOS - 0.223143551
#  ALB - 41.0
#  TPRO - 76.0
#  RBC - 4.117353118
#  LYM - 0.548373617
#  BUN - 1.940419546
#  CCRC - 4.304551461
#  GLU - 1.609437912
#  SYSTOLICBP - 149.0
#  DIASTOLICBP - 88.0
#  PULSE - 77.55306968
#  HEMAT - 0.374200879
#  SPEGRA - 1.020414053
#  LYMperLEU - 25.5447914
#  MONO - 0.407112496
#  MONOperLEU - 6.451450572
#  NEUperLEU - 63.428814
#  POT - 4.6
#  BASOperLEU - 0.447677497
#  EOS - 0.112579001
#  EOSperLEU - 1.907101051
#  TARGET - 0
#  LYMPH_NODES - 0
#  KIDNEYS - 0
#  LUNGS - 1
#  LIVER - 0
#  PLEURA - 1
#  OTHER - 0
#  PROSTATE - 0
#  ORCHIDECTOMY - 0
#  PROSTATECTOMY - 0
#  LYMPHADENECTOMY - 0
#  BILATERAL_ORCHIDECTOMY - 0
#  PRIOR_RADIOTHERAPY - 1
#  ANALGESICS - 0
#  ANTI_ANDROGENS - 1
#  GLUCOCORTICOID - 0
#  GONADOTROPIN - 1
#  BISPHOSPHONATE - 0
#  CORTICOSTEROID - 0
#  IMIDAZOLE - 0
#  ACE_INHIBITORS - 0
#  BETA_BLOCKING - 0
#  HMG_COA_REDUCT - 1
#  ESTROGENS - 0
#  ANTI_ESTROGENS - 0
#  CEREBACC - 0
#  CHF - 0
#  DVT - 0
#  DIAB - 0
#  MI - 0
#  PULMEMB - 0
#  SPINCOMP - 0
#  COPD - 0
#  MHBLOOD - 0
#  MHCARD - 0
#  MHCONGEN - 0
#  MHEAR - 0
#  MHENDO - 0
#  MHGASTRO - 0
#  MHHEPATO - 0
#  MHIMMUNE - 0
#  MHINFECT - 0
#  MHINJURY - 0
#  MHINVEST - 0
#  MHMETAB - 1
#  MHPSYCH - 0
#  MHRENAL - 0
#  MHRESP - 0
#  MHSKIN - 0
#  MHVASC - 0
#  ECOG_C - 0
#  AGEGRP2 - 2
#  RaceAsian - 0
#  RaceBlack - 0
#  RaceOther - 0
#  RaceWhite - 1
#  RegionAsia - 0
#  RegionEastEuro - 0
#  RegionNorthAmer - 0

# %% [markdown]
# # Chi-Square Test for Binary Variables

# %%
binary = ['TARGET',
'LYMPH_NODES',
'KIDNEYS',
'LUNGS',
'LIVER',
'PLEURA',
'OTHER',
'PROSTATE',
'ORCHIDECTOMY',
'PROSTATECTOMY',
'LYMPHADENECTOMY',
'BILATERAL_ORCHIDECTOMY',
'PRIOR_RADIOTHERAPY',
'ANALGESICS',
'ANTI_ANDROGENS',
'GLUCOCORTICOID',
'GONADOTROPIN',
'BISPHOSPHONATE',
'CORTICOSTEROID',
'IMIDAZOLE',
'ACE_INHIBITORS',
'BETA_BLOCKING',
'HMG_COA_REDUCT',
'ESTROGENS',
'ANTI_ESTROGENS',
'CEREBACC',
'CHF',
'DVT',
'DIAB',
'MI',
'PULMEMB',
'SPINCOMP',
'COPD',
'MHBLOOD',
'MHCARD',
'MHCONGEN',
'MHEAR',
'MHENDO',
'MHGASTRO',
'MHHEPATO',
'MHIMMUNE',
'MHINFECT',
'MHINJURY',
'MHINVEST',
'MHMETAB',
'MHPSYCH',
'MHRENAL',
'MHRESP',
'MHSKIN',
'MHVASC',
'ECOG_C',
'AGEGRP2'
]

# %%
binary_stats = pd.DataFrame(columns=['Name', 'chi-2','chi-p', 'Odds-Ratio','fisher-p'])

# %%
# binary_stats.loc[len(binary_stats.index)] = ['Hello',0.05, 6.07]

# %%
def analyse_binary(name):
    print(name)
    table = pd.crosstab(index=data['high_risk'], columns=data[name])
    disp_table = pd.crosstab(index=data['high_risk'], columns=data[name], margins=True)
    display(disp_table)
    chi = chi2_contingency(table)
    if (table.shape == (2,2)):
        oddsr, fisherP = fisher_exact(table)
        print('Fisher Exact Test: \n Odds: %.2f \n p: %.2f' % (oddsr, fisherP))
        binary_stats.loc[len(binary_stats.index)] = [name, chi[0], chi[1], oddsr, fisherP]
    else:
        binary_stats.loc[len(binary_stats.index)] = [
            name, chi[0], chi[1], np.NaN, np.NaN]
    print('\n')

# %%
for feature in binary:
    analyse_binary(feature)
# Out:
# TARGET
# TARGET       0    1  All
# high_risk
# 0           81   85  166
# 1          145  142  287
# All        226  227  453
# Fisher Exact Test:
#  Odds: 0.93
#  p: 0.77
#
#
# LYMPH_NODES
# LYMPH_NODES    0    1  All
# high_risk
# 0             83   83  166
# 1            138  149  287
# All          221  232  453
# Fisher Exact Test:
#  Odds: 1.08
#  p: 0.70
#
#
# KIDNEYS
# KIDNEYS      0  1  All
# high_risk
# 0          164  2  166
# 1          284  3  287
# All        448  5  453
# Fisher Exact Test:
#  Odds: 0.87
#  p: 1.00
#
#
# LUNGS
# LUNGS        0   1  All
# high_risk
# 0          143  23  166
# 1          249  38  287
# All        392  61  453
# Fisher Exact Test:
#  Odds: 0.95
#  p: 0.89
#
#
# LIVER
# LIVER        0   1  All
# high_risk
# 0          157   9  166
# 1          249  38  287
# All        406  47  453
# Fisher Exact Test:
#  Odds: 2.66
#  p: 0.01
#
#
# PLEURA
# PLEURA       0   1  All
# high_risk
# 0          164   2  166
# 1          278   9  287
# All        442  11  453
# Fisher Exact Test:
#  Odds: 2.65
#  p: 0.34
#
#
# OTHER
# OTHER        0  1  All
# high_risk
# 0          165  1  166
# 1          279  8  287
# All        444  9  453
# Fisher Exact Test:
#  Odds: 4.73
#  p: 0.16
#
#
# PROSTATE
# PROSTATE     0   1  All
# high_risk
# 0          142  24  166
# 1          262  25  287
# All        404  49  453
# Fisher Exact Test:
#  Odds: 0.56
#  p: 0.06
#
#
# ORCHIDECTOMY
# ORCHIDECTOMY    0   1  All
# high_risk
# 0             129  37  166
# 1             229  58  287
# All           358  95  453
# Fisher Exact Test:
#  Odds: 0.88
#  p: 0.63
#
#
# PROSTATECTOMY
# PROSTATECTOMY    0    1  All
# high_risk
# 0              113   53  166
# 1              219   68  287
# All            332  121  453
# Fisher Exact Test:
#  Odds: 0.66
#  p: 0.06
#
#
# LYMPHADENECTOMY
# LYMPHADENECTOMY    0   1  All
# high_risk
# 0                138  28  166
# 1                261  26  287
# All              399  54  453
# Fisher Exact Test:
#  Odds: 0.49
#  p: 0.02
#
#
# BILATERAL_ORCHIDECTOMY
# BILATERAL_ORCHIDECTOMY    0   1  All
# high_risk
# 0                       130  36  166
# 1                       244  43  287
# All                     374  79  453
# Fisher Exact Test:
#  Odds: 0.64
#  p: 0.07
#
#
# PRIOR_RADIOTHERAPY
# PRIOR_RADIOTHERAPY    0    1  All
# high_risk
# 0                    77   89  166
# 1                   129  158  287
# All                 206  247  453
# Fisher Exact Test:
#  Odds: 1.06
#  p: 0.77
#
#
# ANALGESICS
# ANALGESICS    0    1  All
# high_risk
# 0           136   30  166
# 1           174  113  287
# All         310  143  453
# Fisher Exact Test:
#  Odds: 2.94
#  p: 0.00
#
#
# ANTI_ANDROGENS
# ANTI_ANDROGENS   0    1  All
# high_risk
# 0               16  150  166
# 1               31  256  287
# All             47  406  453
# Fisher Exact Test:
#  Odds: 0.88
#  p: 0.75
#
#
# GLUCOCORTICOID
# GLUCOCORTICOID    0    1  All
# high_risk
# 0               117   49  166
# 1               174  113  287
# All             291  162  453
# Fisher Exact Test:
#  Odds: 1.55
#  p: 0.04
#
#
# GONADOTROPIN
# GONADOTROPIN   0    1  All
# high_risk
# 0             25  141  166
# 1             49  238  287
# All           74  379  453
# Fisher Exact Test:
#  Odds: 0.86
#  p: 0.60
#
#
# BISPHOSPHONATE
# BISPHOSPHONATE    0    1  All
# high_risk
# 0                93   73  166
# 1               172  115  287
# All             265  188  453
# Fisher Exact Test:
#  Odds: 0.85
#  p: 0.43
#
#
# CORTICOSTEROID
# CORTICOSTEROID    0   1  All
# high_risk
# 0               123  43  166
# 1               244  43  287
# All             367  86  453
# Fisher Exact Test:
#  Odds: 0.50
#  p: 0.01
#
#
# IMIDAZOLE
# IMIDAZOLE    0   1  All
# high_risk
# 0          153  13  166
# 1          264  23  287
# All        417  36  453
# Fisher Exact Test:
#  Odds: 1.03
#  p: 1.00
#
#
# ACE_INHIBITORS
# ACE_INHIBITORS    0    1  All
# high_risk
# 0               122   44  166
# 1               229   58  287
# All             351  102  453
# Fisher Exact Test:
#  Odds: 0.70
#  p: 0.13
#
#
# BETA_BLOCKING
# BETA_BLOCKING    0   1  All
# high_risk
# 0              134  32  166
# 1              227  60  287
# All            361  92  453
# Fisher Exact Test:
#  Odds: 1.11
#  p: 0.72
#
#
# HMG_COA_REDUCT
# HMG_COA_REDUCT    0    1  All
# high_risk
# 0               126   40  166
# 1               221   66  287
# All             347  106  453
# Fisher Exact Test:
#  Odds: 0.94
#  p: 0.82
#
#
# ESTROGENS
# ESTROGENS    0   1  All
# high_risk
# 0          140  26  166
# 1          264  23  287
# All        404  49  453
# Fisher Exact Test:
#  Odds: 0.47
#  p: 0.02
#
#
# ANTI_ESTROGENS
# ANTI_ESTROGENS    0  1  All
# high_risk
# 0               163  3  166
# 1               285  2  287
# All             448  5  453
# Fisher Exact Test:
#  Odds: 0.38
#  p: 0.36
#
#
# CEREBACC
# CEREBACC     0   1  All
# high_risk
# 0          162   4  166
# 1          280   7  287
# All        442  11  453
# Fisher Exact Test:
#  Odds: 1.01
#  p: 1.00
#
#
# CHF
# CHF          0  1  All
# high_risk
# 0          165  1  166
# 1          279  8  287
# All        444  9  453
# Fisher Exact Test:
#  Odds: 4.73
#  p: 0.16
#
#
# DVT
# DVT          0   1  All
# high_risk
# 0          163   3  166
# 1          280   7  287
# All        443  10  453
# Fisher Exact Test:
#  Odds: 1.36
#  p: 0.75
#
#
# DIAB
# DIAB         0   1  All
# high_risk
# 0          135  31  166
# 1          228  59  287
# All        363  90  453
# Fisher Exact Test:
#  Odds: 1.13
#  p: 0.71
#
#
# MI
# MI           0   1  All
# high_risk
# 0          162   4  166
# 1          262  25  287
# All        424  29  453
# Fisher Exact Test:
#  Odds: 3.86
#  p: 0.01
#
#
# PULMEMB
# PULMEMB      0  1  All
# high_risk
# 0          166  0  166
# 1          282  5  287
# All        448  5  453
# Fisher Exact Test:
#  Odds: inf
#  p: 0.16
#
#
# SPINCOMP
# SPINCOMP     0  1  All
# high_risk
# 0          165  1  166
# 1          285  2  287
# All        450  3  453
# Fisher Exact Test:
#  Odds: 1.16
#  p: 1.00
#
#
# COPD
# COPD         0  1  All
# high_risk
# 0          164  2  166
# 1          280  7  287
# All        444  9  453
# Fisher Exact Test:
#  Odds: 2.05
#  p: 0.50
#
#
# MHBLOOD
# MHBLOOD      0   1  All
# high_risk
# 0          162   4  166
# 1          271  16  287
# All        433  20  453
# Fisher Exact Test:
#  Odds: 2.39
#  p: 0.15
#
#
# MHCARD
# MHCARD       0   1  All
# high_risk
# 0          140  26  166
# 1          221  66  287
# All        361  92  453
# Fisher Exact Test:
#  Odds: 1.61
#  p: 0.07
#
#
# MHCONGEN
# MHCONGEN     0  1  All
# high_risk
# 0          162  4  166
# 1          282  5  287
# All        444  9  453
# Fisher Exact Test:
#  Odds: 0.72
#  p: 0.73
#
#
# MHEAR
# MHEAR        0   1  All
# high_risk
# 0          159   7  166
# 1          283   4  287
# All        442  11  453
# Fisher Exact Test:
#  Odds: 0.32
#  p: 0.11
#
#
# MHENDO
# MHENDO       0   1  All
# high_risk
# 0          160   6  166
# 1          283   4  287
# All        443  10  453
# Fisher Exact Test:
#  Odds: 0.38
#  p: 0.18
#
#
# MHGASTRO
# MHGASTRO     0    1  All
# high_risk
# 0          117   49  166
# 1          208   79  287
# All        325  128  453
# Fisher Exact Test:
#  Odds: 0.91
#  p: 0.67
#
#
# MHHEPATO
# MHHEPATO     0   1  All
# high_risk
# 0          160   6  166
# 1          279   8  287
# All        439  14  453
# Fisher Exact Test:
#  Odds: 0.76
#  p: 0.78
#
#
# MHIMMUNE
# MHIMMUNE     0  1  All
# high_risk
# 0          165  1  166
# 1          280  7  287
# All        445  8  453
# Fisher Exact Test:
#  Odds: 4.12
#  p: 0.27
#
#
# MHINFECT
# MHINFECT     0   1  All
# high_risk
# 0          148  18  166
# 1          252  35  287
# All        400  53  453
# Fisher Exact Test:
#  Odds: 1.14
#  p: 0.76
#
#
# MHINJURY
# MHINJURY     0   1  All
# high_risk
# 0          155  11  166
# 1          272  15  287
# All        427  26  453
# Fisher Exact Test:
#  Odds: 0.78
#  p: 0.54
#
#
# MHINVEST
# MHINVEST     0   1  All
# high_risk
# 0          151  15  166
# 1          265  22  287
# All        416  37  453
# Fisher Exact Test:
#  Odds: 0.84
#  p: 0.60
#
#
# MHMETAB
# MHMETAB      0    1  All
# high_risk
# 0          104   62  166
# 1          186  101  287
# All        290  163  453
# Fisher Exact Test:
#  Odds: 0.91
#  p: 0.68
#
#
# MHPSYCH
# MHPSYCH      0   1  All
# high_risk
# 0          156  10  166
# 1          250  37  287
# All        406  47  453
# Fisher Exact Test:
#  Odds: 2.31
#  p: 0.02
#
#
# MHRENAL
# MHRENAL      0   1  All
# high_risk
# 0          137  29  166
# 1          227  60  287
# All        364  89  453
# Fisher Exact Test:
#  Odds: 1.25
#  p: 0.39
#
#
# MHRESP
# MHRESP       0   1  All
# high_risk
# 0          148  18  166
# 1          246  41  287
# All        394  59  453
# Fisher Exact Test:
#  Odds: 1.37
#  p: 0.31
#
#
# MHSKIN
# MHSKIN       0   1  All
# high_risk
# 0          159   7  166
# 1          275  12  287
# All        434  19  453
# Fisher Exact Test:
#  Odds: 0.99
#  p: 1.00
#
#
# MHVASC
# MHVASC       0    1  All
# high_risk
# 0           65  101  166
# 1          168  119  287
# All        233  220  453
# Fisher Exact Test:
#  Odds: 0.46
#  p: 0.00
#
#
# ECOG_C
# ECOG_C       0    1  All
# high_risk
# 0          103   63  166
# 1          104  183  287
# All        207  246  453
# Fisher Exact Test:
#  Odds: 2.88
#  p: 0.00
#
#
# AGEGRP2
# AGEGRP2      0    1    2  All
# high_risk
# 0           49   83   34  166
# 1           89  116   82  287
# All        138  199  116  453

# %%
binary_stats
# Out:
#                       Name      chi-2         chi-p  Odds-Ratio      fisher-p
# 0                   TARGET   0.065947  7.973321e-01    0.933225  7.700713e-01
# 1              LYMPH_NODES   0.087400  7.675095e-01    1.079710  6.977461e-01
# 2                  KIDNEYS   0.096146  7.565040e-01    0.866197  1.000000e+00
# 3                    LUNGS   0.001758  9.665512e-01    0.948839  8.868178e-01
# 4                    LIVER   6.098852  1.352697e-02    2.662204  9.893550e-03
# 5                   PLEURA   0.940559  3.321340e-01    2.654676  3.420187e-01
# 6                    OTHER   1.578574  2.089662e-01    4.731183  1.643145e-01
# 7                 PROSTATE   3.029683  8.175401e-02    0.564567  6.138391e-02
# 8             ORCHIDECTOMY   0.163402  6.860438e-01    0.883040  6.325925e-01
# 9            PROSTATECTOMY   3.234195  7.211574e-02    0.662014  6.148415e-02
# 10         LYMPHADENECTOMY   5.385959  2.029943e-02    0.490969  1.606362e-02
# 11  BILATERAL_ORCHIDECTOMY   2.833942  9.229156e-02    0.636384  7.342565e-02
# 12      PRIOR_RADIOTHERAPY   0.039285  8.428858e-01    1.059664  7.699802e-01
# 13              ANALGESICS  21.113740  4.328137e-06    2.944061  2.021207e-06
# 14          ANTI_ANDROGENS   0.053445  8.171736e-01    0.880860  7.511492e-01
# 15          GLUCOCORTICOID   4.027390  4.476714e-02    1.550669  4.176470e-02
# 16            GONADOTROPIN   0.181908  6.697384e-01    0.861196  6.007174e-01
# 17          BISPHOSPHONATE   0.509887  4.751876e-01    0.851784  4.298936e-01
# 18          CORTICOSTEROID   7.460909  6.305317e-03    0.504098  6.014646e-03
# 19               IMIDAZOLE   0.012326  9.115989e-01    1.025350  1.000000e+00
# 20          ACE_INHIBITORS   2.042948  1.529131e-01    0.702263  1.301808e-01
# 21           BETA_BLOCKING   0.086447  7.687440e-01    1.106828  7.173397e-01
# 38                MHGASTRO   0.119314  7.297799e-01    0.906888  6.659013e-01
# 44                 MHMETAB   0.129220  7.192422e-01    0.910857  6.847983e-01
# 1              LYMPH_NODES   0.087400  7.675095e-01    1.079710  6.977461e-01
# 28                    DIAB   0.130845  7.175577e-01    1.126910  7.141338e-01
# 21           BETA_BLOCKING   0.086447  7.687440e-01    1.106828  7.173397e-01
# 35                MHCONGEN   0.019922  8.877562e-01    0.718085  7.302202e-01
# 14          ANTI_ANDROGENS   0.053445  8.171736e-01    0.880860  7.511492e-01
# 27                     DVT   0.011913  9.130866e-01    1.358333  7.523981e-01
# 41                MHINFECT   0.078178  7.797817e-01    1.141975  7.621429e-01
# 12      PRIOR_RADIOTHERAPY   0.039285  8.428858e-01    1.059664  7.699802e-01
# 0                   TARGET   0.065947  7.973321e-01    0.933225  7.700713e-01
# 39                MHHEPATO   0.043406  8.349635e-01    0.764636  7.790647e-01
# 22          HMG_COA_REDUCT   0.022880  8.797708e-01    0.940724  8.182704e-01
# 3                    LUNGS   0.001758  9.665512e-01    0.948839  8.868178e-01
# 31                SPINCOMP   0.232021  6.300292e-01    1.157895  1.000000e+00
# 19               IMIDAZOLE   0.012326  9.115989e-01    1.025350  1.000000e+00
# 2                  KIDNEYS   0.096146  7.565040e-01    0.866197  1.000000e+00
# 48                  MHSKIN   0.050610  8.220059e-01    0.991169  1.000000e+00
# 25                CEREBACC   0.088310  7.663364e-01    1.012500  1.000000e+00
# 51                 AGEGRP2   4.962612  8.363394e-02         NaN           NaN

# %% [markdown]
# # Continous Variables

# %%
continous = ['BMI',
             'HEIGHTBL',
             'WEIGHTBL',
             'ALP',
             'ALT',
             'AST',
             'CA',
             'CREAT',
             'HB',
             'LDH',
             'NEU',
             'PLT',
             'PSA',
             'TBILI',
             'TESTO',
             'WBC',
             'CREACL',
             'NA.',
             'MG',
             'PHOS',
             'ALB',
             'TPRO',
             'RBC',
             'LYM',
             'BUN',
             'CCRC',
             'GLU',
             'SYSTOLICBP',
             'DIASTOLICBP',
             'PULSE',
             'HEMAT',
             'SPEGRA',
             'LYMperLEU',
             'MONO',
             'MONOperLEU',
             'NEUperLEU',
             'POT',
             'BASOperLEU',
             'EOS',
             'EOSperLEU']

# %%
continous_stats = pd.DataFrame(columns=['Name', 'Stat', 'p'])

# %%
def analyse_continuous(name):
    plt.figure(figsize=(6,4))
    display(sns.boxplot(x="high_risk",y=name, data=data))
    stat, p = ttest_ind(a=data[name][data['high_risk'] == 0], b=data[name][data['high_risk'] == 1])
    continous_stats.loc[len(continous_stats.index)] = [name, stat, p]

# %%
for feature in continous:
    analyse_continuous(feature)
# Out:
# <AxesSubplot:xlabel='high_risk', ylabel='BMI'>
# <AxesSubplot:xlabel='high_risk', ylabel='HEIGHTBL'>
# <AxesSubplot:xlabel='high_risk', ylabel='WEIGHTBL'>
# <AxesSubplot:xlabel='high_risk', ylabel='ALP'>
# <AxesSubplot:xlabel='high_risk', ylabel='ALT'>
# <AxesSubplot:xlabel='high_risk', ylabel='AST'>
# <AxesSubplot:xlabel='high_risk', ylabel='CA'>
# <AxesSubplot:xlabel='high_risk', ylabel='CREAT'>
# <AxesSubplot:xlabel='high_risk', ylabel='HB'>
# <AxesSubplot:xlabel='high_risk', ylabel='LDH'>
# <AxesSubplot:xlabel='high_risk', ylabel='NEU'>
# <AxesSubplot:xlabel='high_risk', ylabel='PLT'>
# <AxesSubplot:xlabel='high_risk', ylabel='PSA'>
# <AxesSubplot:xlabel='high_risk', ylabel='TBILI'>
# <AxesSubplot:xlabel='high_risk', ylabel='TESTO'>
# <AxesSubplot:xlabel='high_risk', ylabel='WBC'>
# <AxesSubplot:xlabel='high_risk', ylabel='CREACL'>
# <AxesSubplot:xlabel='high_risk', ylabel='NA.'>
# <AxesSubplot:xlabel='high_risk', ylabel='MG'>
# <AxesSubplot:xlabel='high_risk', ylabel='PHOS'>
# <ipython-input-164-1f76193a4235>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(6,4))
# <AxesSubplot:xlabel='high_risk', ylabel='ALB'>
# <AxesSubplot:xlabel='high_risk', ylabel='TPRO'>
# <AxesSubplot:xlabel='high_risk', ylabel='RBC'>
# <AxesSubplot:xlabel='high_risk', ylabel='LYM'>
# <AxesSubplot:xlabel='high_risk', ylabel='BUN'>
# <AxesSubplot:xlabel='high_risk', ylabel='CCRC'>
# <AxesSubplot:xlabel='high_risk', ylabel='GLU'>
# <AxesSubplot:xlabel='high_risk', ylabel='SYSTOLICBP'>
# <AxesSubplot:xlabel='high_risk', ylabel='DIASTOLICBP'>
# <AxesSubplot:xlabel='high_risk', ylabel='PULSE'>
# <AxesSubplot:xlabel='high_risk', ylabel='HEMAT'>
# <AxesSubplot:xlabel='high_risk', ylabel='SPEGRA'>
# <AxesSubplot:xlabel='high_risk', ylabel='LYMperLEU'>
# <AxesSubplot:xlabel='high_risk', ylabel='MONO'>
# <AxesSubplot:xlabel='high_risk', ylabel='MONOperLEU'>
# <AxesSubplot:xlabel='high_risk', ylabel='NEUperLEU'>
# <AxesSubplot:xlabel='high_risk', ylabel='POT'>
# <AxesSubplot:xlabel='high_risk', ylabel='BASOperLEU'>
# <AxesSubplot:xlabel='high_risk', ylabel='EOS'>
# <AxesSubplot:xlabel='high_risk', ylabel='EOSperLEU'>

# %%
continous_stats
# Out:
#            Name      Stat             p
# 0           BMI  1.610931  1.078944e-01
# 1      HEIGHTBL -1.583231  1.140697e-01
# 2      WEIGHTBL  0.667325  5.049059e-01
# 3           ALP -9.678116  2.963684e-20
# 4           ALT -0.210303  8.335263e-01
# 5           AST -5.536852  5.236941e-08
# 6            CA  1.491588  1.365064e-01
# 7         CREAT -1.599107  1.104972e-01
# 8            HB  7.463476  4.379378e-13
# 9           LDH -8.490505  3.000787e-16
# 10          NEU -2.954821  3.292295e-03
# 11          PLT -2.892956  4.001105e-03
# 12          PSA -6.449619  2.892593e-10
# 13        TBILI  3.220549  1.371950e-03
# 14        TESTO -3.940831  9.408357e-05
# 15          WBC -0.826205  4.091248e-01
# 16       CREACL  2.008951  4.513775e-02
# 17          NA.  3.072815  2.248948e-03
# 18           MG -1.120526  2.630861e-01
# 19         PHOS  2.612448  9.289717e-03
# 20          ALB  2.014440  4.455644e-02
# 21         TPRO  2.125742  3.406747e-02
# 22          RBC  6.962069  1.189825e-11
# 23          LYM  4.522080  7.837604e-06
# 24          BUN -1.084493  2.787255e-01
# 25         CCRC  2.928799  3.575150e-03
# 26          GLU -2.498040  1.284331e-02
# 27   SYSTOLICBP  3.931870  9.753960e-05
# 28  DIASTOLICBP  3.399615  7.347731e-04
# 29        PULSE -2.022654  4.369841e-02
# 30        HEMAT  7.098806  4.919513e-12
# 31       SPEGRA -0.942337  3.465247e-01
# 32    LYMperLEU  5.586491  4.012952e-08
# 33         MONO -1.057376  2.909062e-01
# 34   MONOperLEU  2.176763  3.001627e-02
# 35    NEUperLEU -5.149448  3.910242e-07
# 36          POT -1.142309  2.539319e-01
# 37   BASOperLEU  0.928418  3.536873e-01
# 38          EOS -0.185831  8.526608e-01
# 39    EOSperLEU  2.327737  2.036760e-02

# %%
continous_stats.sort_values(by='p')
# Out:
#            Name      Stat             p
# 3           ALP -9.678116  2.963684e-20
# 9           LDH -8.490505  3.000787e-16
# 8            HB  7.463476  4.379378e-13
# 30        HEMAT  7.098806  4.919513e-12
# 22          RBC  6.962069  1.189825e-11
# 12          PSA -6.449619  2.892593e-10
# 32    LYMperLEU  5.586491  4.012952e-08
# 5           AST -5.536852  5.236941e-08
# 35    NEUperLEU -5.149448  3.910242e-07
# 23          LYM  4.522080  7.837604e-06
# 14        TESTO -3.940831  9.408357e-05
# 27   SYSTOLICBP  3.931870  9.753960e-05
# 28  DIASTOLICBP  3.399615  7.347731e-04
# 13        TBILI  3.220549  1.371950e-03
# 17          NA.  3.072815  2.248948e-03
# 10          NEU -2.954821  3.292295e-03
# 25         CCRC  2.928799  3.575150e-03
# 11          PLT -2.892956  4.001105e-03
# 19         PHOS  2.612448  9.289717e-03
# 26          GLU -2.498040  1.284331e-02
# 39    EOSperLEU  2.327737  2.036760e-02
# 34   MONOperLEU  2.176763  3.001627e-02
# 21         TPRO  2.125742  3.406747e-02
# 29        PULSE -2.022654  4.369841e-02
# 20          ALB  2.014440  4.455644e-02
# 16       CREACL  2.008951  4.513775e-02
# 0           BMI  1.610931  1.078944e-01
# 7         CREAT -1.599107  1.104972e-01
# 1      HEIGHTBL -1.583231  1.140697e-01
# 6            CA  1.491588  1.365064e-01
# 36          POT -1.142309  2.539319e-01
# 18           MG -1.120526  2.630861e-01
# 24          BUN -1.084493  2.787255e-01
# 33         MONO -1.057376  2.909062e-01
# 31       SPEGRA -0.942337  3.465247e-01
# 37   BASOperLEU  0.928418  3.536873e-01
# 15          WBC -0.826205  4.091248e-01
# 2      WEIGHTBL  0.667325  5.049059e-01
# 4           ALT -0.210303  8.335263e-01
# 38          EOS -0.185831  8.526608e-01
